# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam,SGD

# %%
#Model Creation

inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(256, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping


(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train,100)
y_test = to_categorical(Y_test,100)

from keras.preprocessing.image import ImageDataGenerator
aug_data=ImageDataGenerator(
        rotation_range=20,     #randomly rotate images in the range (20 degrees)
        horizontal_flip=True,  #randomly flip images
        width_shift_range=0.1, #randomly shift images horizontally (fraction of total width)
        shear_range = 0.2,     #Shear Intensity (Shear angle in counter-clockwise direction in degrees)
        height_shift_range=0.1,#randomly shift images vertically (fraction of total height)
        zoom_range=0.2,        #Range for random zoom
        brightness_range = (0.5, 1.5))   #Range for picking a brightness shift value
aug_data.fit(x_train)

# %%
sgd=SGD(learning_rate=0.01,clipnorm=1,momentum=0.9,name='sgd')
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])

checkpoint = ModelCheckpoint('InceptionNet_SGD_NoReg.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
hist=model.fit(aug_data.flow(x_train, y_train, batch_size=128),batch_size=128, epochs=1000, verbose=1, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/1000
# 391/391 [==============================] - ETA: 0s - loss: 4.4058 - accuracy: 0.0322
# Epoch 00001: val_accuracy improved from -inf to 0.06820, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 53s 136ms/step - loss: 4.4058 - accuracy: 0.0322 - val_loss: 4.1249 - val_accuracy: 0.0682
# Epoch 2/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.9992 - accuracy: 0.0886
# Epoch 00002: val_accuracy improved from 0.06820 to 0.13010, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 53s 136ms/step - loss: 3.9992 - accuracy: 0.0886 - val_loss: 3.7506 - val_accuracy: 0.1301
# Epoch 3/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.7322 - accuracy: 0.1307
# Epoch 00003: val_accuracy improved from 0.13010 to 0.15590, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 3.7322 - accuracy: 0.1307 - val_loss: 3.5731 - val_accuracy: 0.1559
# Epoch 4/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.5332 - accuracy: 0.1595
# Epoch 00004: val_accuracy improved from 0.15590 to 0.19590, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 3.5332 - accuracy: 0.1595 - val_loss: 3.3553 - val_accuracy: 0.1959
# Epoch 5/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.4070 - accuracy: 0.1818
# Epoch 00005: val_accuracy improved from 0.19590 to 0.22060, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 3.4070 - accuracy: 0.1818 - val_loss: 3.2047 - val_accuracy: 0.2206
# Epoch 6/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.2916 - accuracy: 0.2040
# Epoch 00006: val_accuracy improved from 0.22060 to 0.24050, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 140ms/step - loss: 3.2916 - accuracy: 0.2040 - val_loss: 3.0931 - val_accuracy: 0.2405
# Epoch 7/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.1823 - accuracy: 0.2215
# Epoch 00007: val_accuracy did not improve from 0.24050
# 391/391 [==============================] - 55s 141ms/step - loss: 3.1823 - accuracy: 0.2215 - val_loss: 3.0987 - val_accuracy: 0.2397
# Epoch 8/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.1239 - accuracy: 0.2339
# Epoch 00008: val_accuracy improved from 0.24050 to 0.28410, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 140ms/step - loss: 3.1239 - accuracy: 0.2339 - val_loss: 2.9158 - val_accuracy: 0.2841
# Epoch 9/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.0409 - accuracy: 0.2516
# Epoch 00009: val_accuracy did not improve from 0.28410
# 391/391 [==============================] - 54s 139ms/step - loss: 3.0409 - accuracy: 0.2516 - val_loss: 2.8936 - val_accuracy: 0.2827
# Epoch 10/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.9891 - accuracy: 0.2580
# Epoch 00010: val_accuracy improved from 0.28410 to 0.30740, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.9891 - accuracy: 0.2580 - val_loss: 2.7976 - val_accuracy: 0.3074
# Epoch 11/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.9340 - accuracy: 0.2704
# Epoch 00011: val_accuracy improved from 0.30740 to 0.31380, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.9340 - accuracy: 0.2704 - val_loss: 2.7577 - val_accuracy: 0.3138
# Epoch 12/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.8746 - accuracy: 0.2814
# Epoch 00012: val_accuracy improved from 0.31380 to 0.31480, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.8746 - accuracy: 0.2814 - val_loss: 2.7499 - val_accuracy: 0.3148
# Epoch 13/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.8467 - accuracy: 0.2873
# Epoch 00013: val_accuracy improved from 0.31480 to 0.31750, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.8467 - accuracy: 0.2873 - val_loss: 2.7357 - val_accuracy: 0.3175
# Epoch 14/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.7869 - accuracy: 0.2971
# Epoch 00014: val_accuracy improved from 0.31750 to 0.32800, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.7869 - accuracy: 0.2971 - val_loss: 2.6620 - val_accuracy: 0.3280
# Epoch 15/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.7504 - accuracy: 0.3064
# Epoch 00015: val_accuracy improved from 0.32800 to 0.33710, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.7504 - accuracy: 0.3064 - val_loss: 2.6258 - val_accuracy: 0.3371
# Epoch 16/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.7165 - accuracy: 0.3125
# Epoch 00016: val_accuracy improved from 0.33710 to 0.35610, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.7165 - accuracy: 0.3125 - val_loss: 2.5362 - val_accuracy: 0.3561
# Epoch 17/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.6735 - accuracy: 0.3241
# Epoch 00017: val_accuracy improved from 0.35610 to 0.35690, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.6735 - accuracy: 0.3241 - val_loss: 2.5247 - val_accuracy: 0.3569
# Epoch 18/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.6321 - accuracy: 0.3291
# Epoch 00018: val_accuracy did not improve from 0.35690
# 391/391 [==============================] - 54s 138ms/step - loss: 2.6321 - accuracy: 0.3291 - val_loss: 2.5240 - val_accuracy: 0.3548
# Epoch 19/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.6069 - accuracy: 0.3369
# Epoch 00019: val_accuracy did not improve from 0.35690
# 391/391 [==============================] - 54s 138ms/step - loss: 2.6069 - accuracy: 0.3369 - val_loss: 2.5601 - val_accuracy: 0.3535
# Epoch 20/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.5704 - accuracy: 0.3425
# Epoch 00020: val_accuracy did not improve from 0.35690
# 391/391 [==============================] - 55s 140ms/step - loss: 2.5704 - accuracy: 0.3425 - val_loss: 2.5295 - val_accuracy: 0.3557
# Epoch 21/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.5470 - accuracy: 0.3480
# Epoch 00021: val_accuracy improved from 0.35690 to 0.37280, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.5470 - accuracy: 0.3480 - val_loss: 2.4252 - val_accuracy: 0.3728
# Epoch 22/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.5076 - accuracy: 0.3553
# Epoch 00022: val_accuracy did not improve from 0.37280
# 391/391 [==============================] - 54s 139ms/step - loss: 2.5076 - accuracy: 0.3553 - val_loss: 2.5166 - val_accuracy: 0.3613
# Epoch 23/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.4889 - accuracy: 0.3587
# Epoch 00023: val_accuracy improved from 0.37280 to 0.38190, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.4889 - accuracy: 0.3587 - val_loss: 2.4068 - val_accuracy: 0.3819
# Epoch 24/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.4645 - accuracy: 0.3658
# Epoch 00024: val_accuracy did not improve from 0.38190
# 391/391 [==============================] - 54s 139ms/step - loss: 2.4645 - accuracy: 0.3658 - val_loss: 2.3948 - val_accuracy: 0.3812
# Epoch 25/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.4436 - accuracy: 0.3674
# Epoch 00025: val_accuracy improved from 0.38190 to 0.38360, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 139ms/step - loss: 2.4436 - accuracy: 0.3674 - val_loss: 2.3931 - val_accuracy: 0.3836
# Epoch 26/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.4113 - accuracy: 0.3766
# Epoch 00026: val_accuracy improved from 0.38360 to 0.38440, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 140ms/step - loss: 2.4113 - accuracy: 0.3766 - val_loss: 2.3982 - val_accuracy: 0.3844
# Epoch 27/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.3925 - accuracy: 0.3809
# Epoch 00027: val_accuracy improved from 0.38440 to 0.39780, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.3925 - accuracy: 0.3809 - val_loss: 2.3473 - val_accuracy: 0.3978
# Epoch 28/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.3578 - accuracy: 0.3883
# Epoch 00028: val_accuracy did not improve from 0.39780
# 391/391 [==============================] - 54s 139ms/step - loss: 2.3578 - accuracy: 0.3883 - val_loss: 2.3577 - val_accuracy: 0.3928
# Epoch 29/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.3485 - accuracy: 0.3885
# Epoch 00029: val_accuracy improved from 0.39780 to 0.41290, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.3485 - accuracy: 0.3885 - val_loss: 2.2615 - val_accuracy: 0.4129
# Epoch 30/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.3245 - accuracy: 0.3943
# Epoch 00030: val_accuracy improved from 0.41290 to 0.41340, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.3245 - accuracy: 0.3943 - val_loss: 2.2446 - val_accuracy: 0.4134
# Epoch 31/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.3013 - accuracy: 0.4008
# Epoch 00031: val_accuracy did not improve from 0.41340
# 391/391 [==============================] - 54s 138ms/step - loss: 2.3013 - accuracy: 0.4008 - val_loss: 2.2835 - val_accuracy: 0.4084
# Epoch 32/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.2762 - accuracy: 0.4045
# Epoch 00032: val_accuracy improved from 0.41340 to 0.41790, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.2762 - accuracy: 0.4045 - val_loss: 2.2447 - val_accuracy: 0.4179
# Epoch 33/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.2638 - accuracy: 0.4085
# Epoch 00033: val_accuracy did not improve from 0.41790
# 391/391 [==============================] - 54s 138ms/step - loss: 2.2638 - accuracy: 0.4085 - val_loss: 2.2398 - val_accuracy: 0.4119
# Epoch 34/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.2330 - accuracy: 0.4123
# Epoch 00034: val_accuracy did not improve from 0.41790
# 391/391 [==============================] - 54s 137ms/step - loss: 2.2330 - accuracy: 0.4123 - val_loss: 2.3414 - val_accuracy: 0.4032
# Epoch 35/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.2291 - accuracy: 0.4157
# Epoch 00035: val_accuracy improved from 0.41790 to 0.42610, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 138ms/step - loss: 2.2291 - accuracy: 0.4157 - val_loss: 2.2179 - val_accuracy: 0.4261
# Epoch 36/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.2117 - accuracy: 0.4145
# Epoch 00036: val_accuracy did not improve from 0.42610
# 391/391 [==============================] - 54s 138ms/step - loss: 2.2117 - accuracy: 0.4145 - val_loss: 2.2125 - val_accuracy: 0.4229
# Epoch 37/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.1834 - accuracy: 0.4244
# Epoch 00037: val_accuracy improved from 0.42610 to 0.43150, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.1834 - accuracy: 0.4244 - val_loss: 2.1777 - val_accuracy: 0.4315
# Epoch 38/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.1810 - accuracy: 0.4264
# Epoch 00038: val_accuracy did not improve from 0.43150
# 391/391 [==============================] - 54s 139ms/step - loss: 2.1810 - accuracy: 0.4264 - val_loss: 2.2752 - val_accuracy: 0.4153
# Epoch 39/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.1637 - accuracy: 0.4281
# Epoch 00039: val_accuracy did not improve from 0.43150
# 391/391 [==============================] - 54s 139ms/step - loss: 2.1637 - accuracy: 0.4281 - val_loss: 2.1848 - val_accuracy: 0.4302
# Epoch 40/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.1571 - accuracy: 0.4310
# Epoch 00040: val_accuracy did not improve from 0.43150
# 391/391 [==============================] - 54s 138ms/step - loss: 2.1571 - accuracy: 0.4310 - val_loss: 2.2556 - val_accuracy: 0.4201
# Epoch 41/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.1268 - accuracy: 0.4355
# Epoch 00041: val_accuracy improved from 0.43150 to 0.43200, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 139ms/step - loss: 2.1268 - accuracy: 0.4355 - val_loss: 2.2004 - val_accuracy: 0.4320
# Epoch 42/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.1141 - accuracy: 0.4386
# Epoch 00042: val_accuracy did not improve from 0.43200
# 391/391 [==============================] - 54s 139ms/step - loss: 2.1141 - accuracy: 0.4386 - val_loss: 2.1706 - val_accuracy: 0.4315
# Epoch 43/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0999 - accuracy: 0.4443
# Epoch 00043: val_accuracy improved from 0.43200 to 0.45690, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 140ms/step - loss: 2.0999 - accuracy: 0.4443 - val_loss: 2.0528 - val_accuracy: 0.4569
# Epoch 44/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0925 - accuracy: 0.4421
# Epoch 00044: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0925 - accuracy: 0.4421 - val_loss: 2.1230 - val_accuracy: 0.4515
# Epoch 45/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0791 - accuracy: 0.4475
# Epoch 00045: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0791 - accuracy: 0.4475 - val_loss: 2.1413 - val_accuracy: 0.4424
# Epoch 46/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0787 - accuracy: 0.4472
# Epoch 00046: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0787 - accuracy: 0.4472 - val_loss: 2.1663 - val_accuracy: 0.4433
# Epoch 47/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0631 - accuracy: 0.4491
# Epoch 00047: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0631 - accuracy: 0.4491 - val_loss: 2.1142 - val_accuracy: 0.4507
# Epoch 48/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0419 - accuracy: 0.4565
# Epoch 00048: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0419 - accuracy: 0.4565 - val_loss: 2.0985 - val_accuracy: 0.4483
# Epoch 49/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0426 - accuracy: 0.4552
# Epoch 00049: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0426 - accuracy: 0.4552 - val_loss: 2.1145 - val_accuracy: 0.4518
# Epoch 50/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0179 - accuracy: 0.4585
# Epoch 00050: val_accuracy did not improve from 0.45690
# 391/391 [==============================] - 55s 140ms/step - loss: 2.0179 - accuracy: 0.4585 - val_loss: 2.0801 - val_accuracy: 0.4545
# Epoch 51/1000
# 391/391 [==============================] - ETA: 0s - loss: 2.0123 - accuracy: 0.4633
# Epoch 00051: val_accuracy improved from 0.45690 to 0.46390, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 2.0123 - accuracy: 0.4633 - val_loss: 2.0515 - val_accuracy: 0.4639
# Epoch 52/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9873 - accuracy: 0.4686
# Epoch 00052: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9873 - accuracy: 0.4686 - val_loss: 2.2952 - val_accuracy: 0.4254
# Epoch 53/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9892 - accuracy: 0.4629
# Epoch 00053: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9892 - accuracy: 0.4629 - val_loss: 2.1056 - val_accuracy: 0.4520
# Epoch 54/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9753 - accuracy: 0.4675
# Epoch 00054: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9753 - accuracy: 0.4675 - val_loss: 2.0808 - val_accuracy: 0.4614
# Epoch 55/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9637 - accuracy: 0.4704
# Epoch 00055: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9637 - accuracy: 0.4704 - val_loss: 2.1541 - val_accuracy: 0.4414
# Epoch 56/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9547 - accuracy: 0.4748
# Epoch 00056: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9547 - accuracy: 0.4748 - val_loss: 2.0897 - val_accuracy: 0.4591
# Epoch 57/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9570 - accuracy: 0.4731
# Epoch 00057: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9570 - accuracy: 0.4731 - val_loss: 2.0790 - val_accuracy: 0.4620
# Epoch 58/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9437 - accuracy: 0.4788
# Epoch 00058: val_accuracy did not improve from 0.46390
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9437 - accuracy: 0.4788 - val_loss: 2.1132 - val_accuracy: 0.4632
# Epoch 59/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9342 - accuracy: 0.4787
# Epoch 00059: val_accuracy improved from 0.46390 to 0.47000, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9342 - accuracy: 0.4787 - val_loss: 2.0436 - val_accuracy: 0.4700
# Epoch 60/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9249 - accuracy: 0.4784
# Epoch 00060: val_accuracy did not improve from 0.47000
# 391/391 [==============================] - 55s 140ms/step - loss: 1.9249 - accuracy: 0.4784 - val_loss: 2.1687 - val_accuracy: 0.4488
# Epoch 61/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.9183 - accuracy: 0.4825
# Epoch 00061: val_accuracy did not improve from 0.47000
# 391/391 [==============================] - 54s 139ms/step - loss: 1.9183 - accuracy: 0.4825 - val_loss: 2.1265 - val_accuracy: 0.4523
# Epoch 62/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8948 - accuracy: 0.4857
# Epoch 00062: val_accuracy improved from 0.47000 to 0.47400, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8948 - accuracy: 0.4857 - val_loss: 1.9851 - val_accuracy: 0.4740
# Epoch 63/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8952 - accuracy: 0.4866
# Epoch 00063: val_accuracy improved from 0.47400 to 0.47810, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8952 - accuracy: 0.4866 - val_loss: 2.0120 - val_accuracy: 0.4781
# Epoch 64/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8884 - accuracy: 0.4876
# Epoch 00064: val_accuracy did not improve from 0.47810
# 391/391 [==============================] - 55s 140ms/step - loss: 1.8884 - accuracy: 0.4876 - val_loss: 2.0846 - val_accuracy: 0.4618
# Epoch 65/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8776 - accuracy: 0.4916
# Epoch 00065: val_accuracy improved from 0.47810 to 0.48110, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 55s 140ms/step - loss: 1.8776 - accuracy: 0.4916 - val_loss: 1.9646 - val_accuracy: 0.4811
# Epoch 66/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8787 - accuracy: 0.4914
# Epoch 00066: val_accuracy did not improve from 0.48110
# 391/391 [==============================] - 55s 139ms/step - loss: 1.8787 - accuracy: 0.4914 - val_loss: 1.9801 - val_accuracy: 0.4783
# Epoch 67/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8584 - accuracy: 0.4977
# Epoch 00067: val_accuracy improved from 0.48110 to 0.50120, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8584 - accuracy: 0.4977 - val_loss: 1.8853 - val_accuracy: 0.5012
# Epoch 68/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8606 - accuracy: 0.4973
# Epoch 00068: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8606 - accuracy: 0.4973 - val_loss: 1.9585 - val_accuracy: 0.4877
# Epoch 69/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8508 - accuracy: 0.4967
# Epoch 00069: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 55s 140ms/step - loss: 1.8508 - accuracy: 0.4967 - val_loss: 2.0102 - val_accuracy: 0.4728
# Epoch 70/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8346 - accuracy: 0.5000
# Epoch 00070: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8346 - accuracy: 0.5000 - val_loss: 2.0156 - val_accuracy: 0.4751
# Epoch 71/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8379 - accuracy: 0.5012
# Epoch 00071: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8379 - accuracy: 0.5012 - val_loss: 2.0568 - val_accuracy: 0.4684
# Epoch 72/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8250 - accuracy: 0.5038
# Epoch 00072: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 55s 140ms/step - loss: 1.8250 - accuracy: 0.5038 - val_loss: 1.9786 - val_accuracy: 0.4880
# Epoch 73/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8148 - accuracy: 0.5075
# Epoch 00073: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 55s 141ms/step - loss: 1.8148 - accuracy: 0.5075 - val_loss: 1.9514 - val_accuracy: 0.4882
# Epoch 74/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8200 - accuracy: 0.5066
# Epoch 00074: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8200 - accuracy: 0.5066 - val_loss: 1.9785 - val_accuracy: 0.4740
# Epoch 75/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8139 - accuracy: 0.5053
# Epoch 00075: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8139 - accuracy: 0.5053 - val_loss: 1.9721 - val_accuracy: 0.4840
# Epoch 76/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8130 - accuracy: 0.5089
# Epoch 00076: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 55s 140ms/step - loss: 1.8130 - accuracy: 0.5089 - val_loss: 2.0319 - val_accuracy: 0.4780
# Epoch 77/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.8042 - accuracy: 0.5106Restoring model weights from the end of the best epoch.
#
# Epoch 00077: val_accuracy did not improve from 0.50120
# 391/391 [==============================] - 54s 139ms/step - loss: 1.8042 - accuracy: 0.5106 - val_loss: 1.9621 - val_accuracy: 0.4888
# Epoch 00077: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.5115064828257802
# Recall: 0.5012
# Accuracy: 0.5012

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# ## Cell to Load Weights and Print Results

# %%
#from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping

inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)

conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(256, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping

(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train,100)
y_test = to_categorical(Y_test,100)

#model = create_model()
model.load_weights('../weights/InceptionNet_SGD_NoReg.hdf5')

y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Using TensorFlow backend.
# Prec: 0.5115064828257802
# Recall: 0.5012
# Accuracy: 0.5012
