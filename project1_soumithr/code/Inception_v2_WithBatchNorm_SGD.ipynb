# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam,SGD

#Create Model
inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = BatchNormalization(axis = 3)(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = BatchNormalization(axis = 3)(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = BatchNormalization(axis = 3)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)
conv_2 = BatchNormalization(axis = 3)(conv_2)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = BatchNormalization(axis = 3)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)
conv_2 = BatchNormalization(axis = 3)(conv_2)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = BatchNormalization(axis = 3)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)
conv_2 = BatchNormalization(axis = 3)(conv_2)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception4
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_11 = BatchNormalization(axis = 3)(conv_11)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)
conv_12 = BatchNormalization(axis = 3)(conv_12)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_21 = BatchNormalization(axis = 3)(conv_21)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)
conv_22 = BatchNormalization(axis = 3)(conv_22)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(256, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping
import datetime
import os

(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train,100)
y_test = to_categorical(Y_test,100)


from keras.preprocessing.image import ImageDataGenerator
aug_data=ImageDataGenerator(
        rotation_range=20,     #randomly rotate images in the range (20 degrees)
        horizontal_flip=True,  #randomly flip images
        width_shift_range=0.1, #randomly shift images horizontally (fraction of total width)
        shear_range = 0.2,     #Shear Intensity (Shear angle in counter-clockwise direction in degrees)
        height_shift_range=0.1,#randomly shift images vertically (fraction of total height)
        zoom_range=0.2,        #Range for random zoom
        brightness_range = (0.5, 1.5))   #Range for picking a brightness shift value
aug_data.fit(x_train)

sgd=SGD(learning_rate=0.01,clipnorm=1,momentum=0.9,name='sgd')
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])

checkpoint = ModelCheckpoint('InceptionNet_SGD_NoReg.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
hist=model.fit(aug_data.flow(x_train, y_train, batch_size=128),batch_size=128, epochs=1000, verbose=1, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/1000
# 391/391 [==============================] - ETA: 0s - loss: 4.2611 - accuracy: 0.0535
# Epoch 00001: val_accuracy improved from -inf to 0.05250, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 72s 184ms/step - loss: 4.2611 - accuracy: 0.0535 - val_loss: 4.3946 - val_accuracy: 0.0525
# Epoch 2/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.7265 - accuracy: 0.1286
# Epoch 00002: val_accuracy improved from 0.05250 to 0.12090, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 3.7265 - accuracy: 0.1286 - val_loss: 3.8169 - val_accuracy: 0.1209
# Epoch 3/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.4349 - accuracy: 0.1792
# Epoch 00003: val_accuracy improved from 0.12090 to 0.17990, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 3.4349 - accuracy: 0.1792 - val_loss: 3.5044 - val_accuracy: 0.1799
# Epoch 4/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.2111 - accuracy: 0.2175
# Epoch 00004: val_accuracy improved from 0.17990 to 0.23120, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 180ms/step - loss: 3.2111 - accuracy: 0.2175 - val_loss: 3.2230 - val_accuracy: 0.2312
# Epoch 5/1000
# 391/391 [==============================] - ETA: 0s - loss: 3.0397 - accuracy: 0.2491
# Epoch 00005: val_accuracy improved from 0.23120 to 0.24620, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s
1000
# 391/391 [==============================] - ETA: 0s - loss: 1.6515 - accuracy: 0.5401
# Epoch 00034: val_accuracy did not improve from 0.50610
# 391/391 [==============================] - 71s 181ms/step - loss: 1.6515 - accuracy: 0.5401 - val_loss: 2.1285 - val_accuracy: 0.4716
# Epoch 35/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.6298 - accuracy: 0.5473
# Epoch 00035: val_accuracy did not improve from 0.50610
# 391/391 [==============================] - 71s 181ms/step - loss: 1.6298 - accuracy: 0.5473 - val_loss: 1.9683 - val_accuracy: 0.5035
# Epoch 36/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.6234 - accuracy: 0.5467
# Epoch 00036: val_accuracy did not improve from 0.50610
# 391/391 [==============================] - 71s 181ms/step - loss: 1.6234 - accuracy: 0.5467 - val_loss: 1.9211 - val_accuracy: 0.5041
# Epoch 37/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.5967 - accuracy: 0.5551
# Epoch 00037: val_accuracy improved from 0.50610 to 0.50760, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 1.5967 - accuracy: 0.5551 - val_loss: 1.8947 - val_accuracy: 0.5076
# Epoch 38/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.5868 - accuracy: 0.5563
# Epoch 00038: val_accuracy improved from 0.50760 to 0.52560, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 1.5868 - accuracy: 0.5563 - val_loss: 1.7992 - val_accuracy: 0.5256
# Epoch 39/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.5718 - accuracy: 0.5601
# Epoch 00039: val_accuracy improved from 0.52560 to 0.52720, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 70s 180ms/step - loss: 1.5718 - accuracy: 0.5601 - val_loss: 1.7956 - val_accuracy: 0.5272
# Epoch 40/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.5484 - accuracy: 0.5663
# Epoch 00040: val_accuracy did not improve from 0.52720
# 391/391 [==============================] - 70s 179ms/step - loss: 1.5484 - accuracy: 0.5663 - val_loss: 1.8974 - val_accuracy: 0.5078
# Epoch 41/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.5361 - accuracy: 0.5689
# Epoch 00041: val_accuracy improved from 0.52720 to 0.53300, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 70s 179ms/step - loss: 1.5361 - accuracy: 0.5689 - val_loss: 1.7570 - val_accuracy: 0.5330
# Epoch 42/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.5126 - accuracy: 0.5735
# Epoch 00042: val_accuracy did not improve from 0.53300
# 391/391 [==============================] - 70s 178ms/step - loss: 1.5126 - accuracy: 0.5735 - val_loss: 1.8135 - val_accuracy: 0.5277
# Epoch 43/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4916 - accuracy: 0.5803
# Epoch 00043: val_accuracy did not improve from 0.53300
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4916 - accuracy: 0.5803 - val_loss: 1.8180 - val_accuracy: 0.5277
# Epoch 44/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4940 - accuracy: 0.5773
# Epoch 00044: val_accuracy did not improve from 0.53300
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4940 - accuracy: 0.5773 - val_loss: 1.8385 - val_accuracy: 0.5262
# Epoch 45/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4754 - accuracy: 0.5846
# Epoch 00045: val_accuracy did not improve from 0.53300
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4754 - accuracy: 0.5846 - val_loss: 1.8164 - val_accuracy: 0.5193
# Epoch 46/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4522 - accuracy: 0.5905
# Epoch 00046: val_accuracy did not improve from 0.53300
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4522 - accuracy: 0.5905 - val_loss: 1.8102 - val_accuracy: 0.5302
# Epoch 47/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4409 - accuracy: 0.5931
# Epoch 00047: val_accuracy did not improve from 0.53300
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4409 - accuracy: 0.5931 - val_loss: 1.8986 - val_accuracy: 0.5110
# Epoch 48/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4315 - accuracy: 0.5936
# Epoch 00048: val_accuracy improved from 0.53300 to 0.53580, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4315 - accuracy: 0.5936 - val_loss: 1.8021 - val_accuracy: 0.5358
# Epoch 49/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4145 - accuracy: 0.5967
# Epoch 00049: val_accuracy did not improve from 0.53580
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4145 - accuracy: 0.5967 - val_loss: 1.8043 - val_accuracy: 0.5349
# Epoch 50/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.4074 - accuracy: 0.5974
# Epoch 00050: val_accuracy did not improve from 0.53580
# 391/391 [==============================] - 71s 181ms/step - loss: 1.4074 - accuracy: 0.5974 - val_loss: 1.9689 - val_accuracy: 0.5057
# Epoch 51/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3955 - accuracy: 0.6015
# Epoch 00051: val_accuracy improved from 0.53580 to 0.55120, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 1.3955 - accuracy: 0.6015 - val_loss: 1.7102 - val_accuracy: 0.5512
# Epoch 52/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3871 - accuracy: 0.6020
# Epoch 00052: val_accuracy improved from 0.55120 to 0.55480, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 71s 181ms/step - loss: 1.3871 - accuracy: 0.6020 - val_loss: 1.7255 - val_accuracy: 0.5548
# Epoch 53/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3718 - accuracy: 0.6089
# Epoch 00053: val_accuracy did not improve from 0.55480
# 391/391 [==============================] - 71s 181ms/step - loss: 1.3718 - accuracy: 0.6089 - val_loss: 1.8646 - val_accuracy: 0.5233
# Epoch 54/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3551 - accuracy: 0.6103
# Epoch 00054: val_accuracy did not improve from 0.55480
# 391/391 [==============================] - 71s 181ms/step - loss: 1.3551 - accuracy: 0.6103 - val_loss: 1.7639 - val_accuracy: 0.5415
# Epoch 55/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3518 - accuracy: 0.6131
# Epoch 00055: val_accuracy did not improve from 0.55480
# 391/391 [==============================] - 70s 180ms/step - loss: 1.3518 - accuracy: 0.6131 - val_loss: 1.7950 - val_accuracy: 0.5309
# Epoch 56/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3402 - accuracy: 0.6176
# Epoch 00056: val_accuracy did not improve from 0.55480
# 391/391 [==============================] - 70s 179ms/step - loss: 1.3402 - accuracy: 0.6176 - val_loss: 1.7974 - val_accuracy: 0.5378
# Epoch 57/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3276 - accuracy: 0.6187
# Epoch 00057: val_accuracy did not improve from 0.55480
# 391/391 [==============================] - 70s 179ms/step - loss: 1.3276 - accuracy: 0.6187 - val_loss: 1.7075 - val_accuracy: 0.5490
# Epoch 58/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3230 - accuracy: 0.6208
# Epoch 00058: val_accuracy improved from 0.55480 to 0.56150, saving model to InceptionNet_SGD_NoReg.hdf5
# 391/391 [==============================] - 70s 179ms/step - loss: 1.3230 - accuracy: 0.6208 - val_loss: 1.6629 - val_accuracy: 0.5615
# Epoch 59/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.3129 - accuracy: 0.6235
# Epoch 00059: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 178ms/step - loss: 1.3129 - accuracy: 0.6235 - val_loss: 1.7419 - val_accuracy: 0.5440
# Epoch 60/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2993 - accuracy: 0.6306
# Epoch 00060: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2993 - accuracy: 0.6306 - val_loss: 1.8086 - val_accuracy: 0.5448
# Epoch 61/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2823 - accuracy: 0.6312
# Epoch 00061: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2823 - accuracy: 0.6312 - val_loss: 1.7848 - val_accuracy: 0.5437
# Epoch 62/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2742 - accuracy: 0.6326
# Epoch 00062: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2742 - accuracy: 0.6326 - val_loss: 1.8617 - val_accuracy: 0.5260
# Epoch 63/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2813 - accuracy: 0.6327
# Epoch 00063: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2813 - accuracy: 0.6327 - val_loss: 1.7047 - val_accuracy: 0.5570
# Epoch 64/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2537 - accuracy: 0.6361
# Epoch 00064: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2537 - accuracy: 0.6361 - val_loss: 1.7961 - val_accuracy: 0.5446
# Epoch 65/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2490 - accuracy: 0.6399
# Epoch 00065: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 178ms/step - loss: 1.2490 - accuracy: 0.6399 - val_loss: 1.8780 - val_accuracy: 0.5285
# Epoch 66/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2489 - accuracy: 0.6387
# Epoch 00066: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2489 - accuracy: 0.6387 - val_loss: 1.7435 - val_accuracy: 0.5520
# Epoch 67/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2414 - accuracy: 0.6411
# Epoch 00067: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2414 - accuracy: 0.6411 - val_loss: 1.8153 - val_accuracy: 0.5404
# Epoch 68/1000
# 391/391 [==============================] - ETA: 0s - loss: 1.2266 - accuracy: 0.6451Restoring model weights from the end of the best epoch.
#
# Epoch 00068: val_accuracy did not improve from 0.56150
# 391/391 [==============================] - 70s 179ms/step - loss: 1.2266 - accuracy: 0.6451 - val_loss: 1.8001 - val_accuracy: 0.5396
# Epoch 00068: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.584785675189367
# Recall: 0.5615
# Accuracy: 0.5615

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# ## Cell to Load Weights and Print Results

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense, Dropout,ZeroPadding2D,MaxPool2D,concatenate
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam,SGD

inputs = Input(shape=(32, 32, 3))
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(inputs)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = BatchNormalization(axis = 3)(X)
X = MaxPool2D((3,3), strides=(1,1), padding='same')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = Conv2D(32, (3,3), strides = (1,1),padding='same',activation='relu')(X)
X = BatchNormalization(axis = 3)(X)

#Inception1
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_1 = BatchNormalization(axis = 3)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_2)
conv_2 = BatchNormalization(axis = 3)(conv_2)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)

#Inception2
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = BatchNormalization(axis = 3)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)
conv_2 = BatchNormalization(axis = 3)(conv_2)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception3
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_1)
conv_1 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_1)
conv_1 = BatchNormalization(axis = 3)(conv_1)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_2 = Conv2D(32, (1,7), padding='same', activation='relu')(conv_2)
conv_2 = Conv2D(32, (7,1), padding='same', activation='relu')(conv_2)
conv_2 = BatchNormalization(axis = 3)(conv_2)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_1,conv_2,conv_3,conv_4], axis=3)


#Inception4
conv_1 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_1 = Conv2D(32, (3,3), padding='same', activation='relu')(conv_1)
conv_11 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_1)
conv_11 = BatchNormalization(axis = 3)(conv_11)
conv_12 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_1)
conv_12 = BatchNormalization(axis = 3)(conv_12)

conv_2 = Conv2D(32, (1,1), padding='same', activation='relu')(X)
conv_21 = Conv2D(32, (1,3), padding='same', activation='relu')(conv_2)
conv_21 = BatchNormalization(axis = 3)(conv_21)
conv_22 = Conv2D(32, (3,1), padding='same', activation='relu')(conv_2)
conv_22 = BatchNormalization(axis = 3)(conv_22)

bn = BatchNormalization(axis = 3)(X)
conv_3 = MaxPool2D((3,3), strides=(1,1), padding='same')(bn)
conv_3 = Conv2D(32, (1,1), padding='same', activation='relu')(conv_3)

conv_4 = Conv2D(32, (1,1), padding='same', activation='relu')(X)

X = concatenate([conv_11,conv_12,conv_21,conv_22,conv_3,conv_4], axis=3)


X = Conv2D(32, 3, activation='relu')(X)
X = Conv2D(64, 3, activation='relu')(X)
X = AveragePooling2D(4)(X)
X = Flatten()(X)
X = Dense(256, activation='relu')(X)
outputs = Dense(100, activation='softmax')(X)

model = Model(inputs, outputs)

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping

(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train,100)
y_test = to_categorical(Y_test,100)

model.load_weights('../weights/Inception_BatchNorm_SGD.hdf5')


# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
