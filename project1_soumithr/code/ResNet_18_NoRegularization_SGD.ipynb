# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam,SGD

#Create Model
def relu_bn(inputs: Tensor) -> Tensor:
    relu = ReLU()(inputs)
    #bn = BatchNormalization()(relu)
    return relu

def residual_block(x: Tensor, downsample: bool, filters: int, kernel_size: int = 3) -> Tensor:
    y = Conv2D(kernel_size=kernel_size,strides= (1 if not downsample else 2),filters=filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(x)
    y = relu_bn(y)
    y = Conv2D(kernel_size=kernel_size,strides=1,filters=filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(y)

    if downsample:
        x = Conv2D(kernel_size=1,strides=2,filters=filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(x)

    out = Add()([x, y])
    out = relu_bn(out)
    return out

def create_res_net():
    
    inputs = Input(shape=(32, 32, 3))
    num_filters = 64
    
    #t = BatchNormalization()(inputs)
    t = Conv2D(kernel_size=3,strides=1,filters=num_filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(inputs)
    t = relu_bn(t)
    
    num_blocks_list = [2,2,2,2]
    for i in range(len(num_blocks_list)):
        num_blocks = num_blocks_list[i]
        for j in range(num_blocks):
            t = residual_block(t, downsample=(j==0 and i!=0), filters=num_filters)
        num_filters *= 2
    
    t = AveragePooling2D(4)(t)
    t = Flatten()(t)
    t = Dense(512,activation='relu')(t)
    outputs = Dense(100, activation='softmax')(t)
    model = Model(inputs, outputs)
    sgd=SGD(learning_rate=0.01,momentum=0.9,clipnorm=1,name='sgd')
    model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])

    return model

# %% [markdown]
# Code snippet taken and modified from https://towardsdatascience.com/building-a-resnet-in-keras-e8f1322a49ba

# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping
from keras.utils import to_categorical

(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255

y_train = to_categorical(Y_train,100)
y_test = to_categorical(Y_test,100)

model = create_res_net() 
model.summary()

from keras.preprocessing.image import ImageDataGenerator
aug_data=ImageDataGenerator(
        rotation_range=20,     #randomly rotate images in the range (20 degrees)
        horizontal_flip=True,  #randomly flip images
        width_shift_range=0.1, #randomly shift images horizontally (fraction of total width)
        shear_range = 0.2,     #Shear Intensity (Shear angle in counter-clockwise direction in degrees)
        height_shift_range=0.1,#randomly shift images vertically (fraction of total height)
        zoom_range=0.2,        #Range for random zoom
        brightness_range = (0.5, 1.5))   #Range for picking a brightness shift value
aug_data.fit(x_train)

# save model after each epoch
checkpoint = ModelCheckpoint('ResNet_Basic_SGD.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
hist=model.fit(aug_data.flow(x_train, y_train, batch_size=128), batch_size=128, epochs=100, verbose=1, validation_data=(x_test, y_test),callbacks=[early,checkpoint])
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 64)   1792        input_2[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 32, 32, 64)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 64)   36928       re_lu_17[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 32, 32, 64)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 64)   36928       re_lu_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 64)   0           re_lu_17[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 32, 32, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   36928       re_lu_19[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 32, 32, 64)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   36928       re_lu_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 32, 64)   0           re_lu_19[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 32, 32, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 128)  73856       re_lu_21[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 16, 16, 128)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  8320        re_lu_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 128)  0           conv2d_27[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 16, 16, 128)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_23[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 16, 16, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 128)  147584      re_lu_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 128)  0           re_lu_23[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 16, 16, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 256)    295168      re_lu_25[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 8, 8, 256)    0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 256)    33024       re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 256)    590080      re_lu_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 256)    0           conv2d_32[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 8, 8, 256)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 256)    590080      re_lu_27[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 8, 8, 256)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 256)    590080      re_lu_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 256)    0           re_lu_27[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 8, 8, 256)    0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 4, 4, 512)    1180160     re_lu_29[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 4, 4, 512)    0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 512)    131584      re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 512)    2359808     re_lu_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 512)    0           conv2d_37[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 4, 4, 512)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 512)    2359808     re_lu_31[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 4, 4, 512)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 512)    2359808     re_lu_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 512)    0           re_lu_31[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 4, 4, 512)    0           add_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           re_lu_33[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          51300       dense_2[0][0]
# ==================================================================================================
# Total params: 11,477,988
# Trainable params: 11,477,988
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
#   2/391 [..............................] - ETA: 25s - loss: 30.4805 - accuracy: 0.0039   WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0543s vs `on_train_batch_end` time: 0.0871s). Check your callbacks.
# 391/391 [==============================] - ETA: 0s - loss: 4.4375 - accuracy: 0.0500
# Epoch 00001: val_accuracy improved from -inf to 0.09350, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 50s 129ms/step - loss: 4.4375 - accuracy: 0.0500 - val_loss: 3.9408 - val_accuracy: 0.0935
# Epoch 2/100
# 391/391 [==============================] - ETA: 0s - loss: 3.8387 - accuracy: 0.1106
# Epoch 00002: val_accuracy improved from 0.09350 to 0.14900, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 3.8387 - accuracy: 0.1106 - val_loss: 3.6226 - val_accuracy: 0.1490
# Epoch 3/100
# 391/391 [==============================] - ETA: 0s - loss: 3.5490 - accuracy: 0.1611
# Epoch 00003: val_accuracy improved from 0.14900 to 0.16950, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 3.5490 - accuracy: 0.1611 - val_loss: 3.4483 - val_accuracy: 0.1695
# Epoch 4/100
# 391/391 [==============================] - ETA: 0s - loss: 3.3404 - accuracy: 0.2000
# Epoch 00004: val_accuracy improved from 0.16950 to 0.21820, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 3.3404 - accuracy: 0.2000 - val_loss: 3.1944 - val_accuracy: 0.2182
# Epoch 5/100
# 391/391 [==============================] - ETA: 0s - loss: 3.1712 - accuracy: 0.2291
# Epoch 00005: val_accuracy improved from 0.21820 to 0.24220, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 3.1712 - accuracy: 0.2291 - val_loss: 3.0560 - val_accuracy: 0.2422
# Epoch 6/100
# 391/391 [==============================] - ETA: 0s - loss: 3.0154 - accuracy: 0.2606
# Epoch 00006: val_accuracy improved from 0.24220 to 0.29510, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 3.0154 - accuracy: 0.2606 - val_loss: 2.8179 - val_accuracy: 0.2951
# Epoch 7/100
# 391/391 [==============================] - ETA: 0s - loss: 2.8600 - accuracy: 0.2920
# Epoch 00007: val_accuracy improved from 0.29510 to 0.31960, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.8600 - accuracy: 0.2920 - val_loss: 2.7309 - val_accuracy: 0.3196
# Epoch 8/100
# 391/391 [==============================] - ETA: 0s - loss: 2.7247 - accuracy: 0.3212
# Epoch 00008: val_accuracy improved from 0.31960 to 0.34620, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.7247 - accuracy: 0.3212 - val_loss: 2.5613 - val_accuracy: 0.3462
# Epoch 9/100
# 391/391 [==============================] - ETA: 0s - loss: 2.6222 - accuracy: 0.3399
# Epoch 00009: val_accuracy improved from 0.34620 to 0.35170, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.6222 - accuracy: 0.3399 - val_loss: 2.5187 - val_accuracy: 0.3517
# Epoch 10/100
# 391/391 [==============================] - ETA: 0s - loss: 2.5046 - accuracy: 0.3641
# Epoch 00010: val_accuracy improved from 0.35170 to 0.37400, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.5046 - accuracy: 0.3641 - val_loss: 2.4517 - val_accuracy: 0.3740
# Epoch 11/100
# 391/391 [==============================] - ETA: 0s - loss: 2.4151 - accuracy: 0.3847
# Epoch 00011: val_accuracy improved from 0.37400 to 0.40000, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.4151 - accuracy: 0.3847 - val_loss: 2.3551 - val_accuracy: 0.4000
# Epoch 12/100
# 391/391 [==============================] - ETA: 0s - loss: 2.3272 - accuracy: 0.4009
# Epoch 00012: val_accuracy improved from 0.40000 to 0.42090, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.3272 - accuracy: 0.4009 - val_loss: 2.2461 - val_accuracy: 0.4209
# Epoch 13/100
# 391/391 [==============================] - ETA: 0s - loss: 2.2355 - accuracy: 0.4217
# Epoch 00013: val_accuracy improved from 0.42090 to 0.44200, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 2.2355 - accuracy: 0.4217 - val_loss: 2.1359 - val_accuracy: 0.4420
# Epoch 14/100
# 391/391 [==============================] - ETA: 0s - loss: 2.1652 - accuracy: 0.4360
# Epoch 00014: val_accuracy did not improve from 0.44200
# 391/391 [==============================] - 51s 129ms/step - loss: 2.1652 - accuracy: 0.4360 - val_loss: 2.2483 - val_accuracy: 0.4257
# Epoch 15/100
# 391/391 [==============================] - ETA: 0s - loss: 2.1005 - accuracy: 0.4506
# Epoch 00015: val_accuracy improved from 0.44200 to 0.45320, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 2.1005 - accuracy: 0.4506 - val_loss: 2.0953 - val_accuracy: 0.4532
# Epoch 16/100
# 391/391 [==============================] - ETA: 0s - loss: 2.0259 - accuracy: 0.4680
# Epoch 00016: val_accuracy improved from 0.45320 to 0.46440, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 52s 132ms/step - loss: 2.0259 - accuracy: 0.4680 - val_loss: 2.0430 - val_accuracy: 0.4644
# Epoch 17/100
# 391/391 [==============================] - ETA: 0s - loss: 1.9551 - accuracy: 0.4843
# Epoch 00017: val_accuracy did not improve from 0.46440
# 391/391 [==============================] - 51s 131ms/step - loss: 1.9551 - accuracy: 0.4843 - val_loss: 2.0974 - val_accuracy: 0.4464
# Epoch 18/100
# 391/391 [==============================] - ETA: 0s - loss: 1.8931 - accuracy: 0.4976
# Epoch 00018: val_accuracy improved from 0.46440 to 0.46910, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 52s 133ms/step - loss: 1.8931 - accuracy: 0.4976 - val_loss: 2.0748 - val_accuracy: 0.4691
# Epoch 19/100
# 391/391 [==============================] - ETA: 0s - loss: 1.8359 - accuracy: 0.5123
# Epoch 00019: val_accuracy improved from 0.46910 to 0.47680, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 52s 132ms/step - loss: 1.8359 - accuracy: 0.5123 - val_loss: 1.9645 - val_accuracy: 0.4768
# Epoch 20/100
# 391/391 [==============================] - ETA: 0s - loss: 1.7855 - accuracy: 0.5213
# Epoch 00020: val_accuracy improved from 0.47680 to 0.48440, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 52s 133ms/step - loss: 1.7855 - accuracy: 0.5213 - val_loss: 2.0206 - val_accuracy: 0.4844
# Epoch 21/100
# 391/391 [==============================] - ETA: 0s - loss: 1.7338 - accuracy: 0.5340
# Epoch 00021: val_accuracy did not improve from 0.48440
# 391/391 [==============================] - 51s 131ms/step - loss: 1.7338 - accuracy: 0.5340 - val_loss: 2.1635 - val_accuracy: 0.4682
# Epoch 22/100
# 391/391 [==============================] - ETA: 0s - loss: 1.6825 - accuracy: 0.5468
# Epoch 00022: val_accuracy improved from 0.48440 to 0.50500, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 1.6825 - accuracy: 0.5468 - val_loss: 1.9132 - val_accuracy: 0.5050
# Epoch 23/100
# 391/391 [==============================] - ETA: 0s - loss: 1.6337 - accuracy: 0.5560
# Epoch 00023: val_accuracy improved from 0.50500 to 0.51260, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 52s 132ms/step - loss: 1.6337 - accuracy: 0.5560 - val_loss: 1.8863 - val_accuracy: 0.5126
# Epoch 24/100
# 391/391 [==============================] - ETA: 0s - loss: 1.5954 - accuracy: 0.5658
# Epoch 00024: val_accuracy did not improve from 0.51260
# 391/391 [==============================] - 51s 130ms/step - loss: 1.5954 - accuracy: 0.5658 - val_loss: 2.1314 - val_accuracy: 0.4793
# Epoch 25/100
# 391/391 [==============================] - ETA: 0s - loss: 1.5440 - accuracy: 0.5789
# Epoch 00025: val_accuracy did not improve from 0.51260
# 391/391 [==============================] - 51s 131ms/step - loss: 1.5440 - accuracy: 0.5789 - val_loss: 2.0248 - val_accuracy: 0.4994
# Epoch 26/100
# 391/391 [==============================] - ETA: 0s - loss: 1.5081 - accuracy: 0.5864
# Epoch 00026: val_accuracy improved from 0.51260 to 0.52980, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 130ms/step - loss: 1.5081 - accuracy: 0.5864 - val_loss: 1.8288 - val_accuracy: 0.5298
# Epoch 27/100
# 391/391 [==============================] - ETA: 0s - loss: 1.4691 - accuracy: 0.5962
# Epoch 00027: val_accuracy did not improve from 0.52980
# 391/391 [==============================] - 51s 130ms/step - loss: 1.4691 - accuracy: 0.5962 - val_loss: 1.9606 - val_accuracy: 0.5121
# Epoch 28/100
# 391/391 [==============================] - ETA: 0s - loss: 1.4344 - accuracy: 0.6059
# Epoch 00028: val_accuracy did not improve from 0.52980
# 391/391 [==============================] - 50s 129ms/step - loss: 1.4344 - accuracy: 0.6059 - val_loss: 1.9604 - val_accuracy: 0.5210
# Epoch 29/100
# 391/391 [==============================] - ETA: 0s - loss: 1.3919 - accuracy: 0.6141
# Epoch 00029: val_accuracy did not improve from 0.52980
# 391/391 [==============================] - 51s 131ms/step - loss: 1.3919 - accuracy: 0.6141 - val_loss: 1.9181 - val_accuracy: 0.5233
# Epoch 30/100
# 391/391 [==============================] - ETA: 0s - loss: 1.3607 - accuracy: 0.6246
# Epoch 00030: val_accuracy improved from 0.52980 to 0.54160, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 52s 132ms/step - loss: 1.3607 - accuracy: 0.6246 - val_loss: 1.8524 - val_accuracy: 0.5416
# Epoch 31/100
# 391/391 [==============================] - ETA: 0s - loss: 1.3218 - accuracy: 0.6312
# Epoch 00031: val_accuracy improved from 0.54160 to 0.54610, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 1.3218 - accuracy: 0.6312 - val_loss: 1.8079 - val_accuracy: 0.5461
# Epoch 32/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2935 - accuracy: 0.6375
# Epoch 00032: val_accuracy did not improve from 0.54610
# 391/391 [==============================] - 51s 131ms/step - loss: 1.2935 - accuracy: 0.6375 - val_loss: 1.8857 - val_accuracy: 0.5429
# Epoch 33/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2690 - accuracy: 0.6448
# Epoch 00033: val_accuracy improved from 0.54610 to 0.54820, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 1.2690 - accuracy: 0.6448 - val_loss: 1.7604 - val_accuracy: 0.5482
# Epoch 34/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2300 - accuracy: 0.6561
# Epoch 00034: val_accuracy did not improve from 0.54820
# 391/391 [==============================] - 51s 131ms/step - loss: 1.2300 - accuracy: 0.6561 - val_loss: 1.8736 - val_accuracy: 0.5451
# Epoch 35/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2006 - accuracy: 0.6610
# Epoch 00035: val_accuracy did not improve from 0.54820
# 391/391 [==============================] - 51s 131ms/step - loss: 1.2006 - accuracy: 0.6610 - val_loss: 1.9319 - val_accuracy: 0.5370
# Epoch 36/100
# 391/391 [==============================] - ETA: 0s - loss: 1.1758 - accuracy: 0.6697
# Epoch 00036: val_accuracy did not improve from 0.54820
# 391/391 [==============================] - 51s 131ms/step - loss: 1.1758 - accuracy: 0.6697 - val_loss: 1.8520 - val_accuracy: 0.5422
# Epoch 37/100
# 391/391 [==============================] - ETA: 0s - loss: 1.1431 - accuracy: 0.6772
# Epoch 00037: val_accuracy improved from 0.54820 to 0.55490, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 1.1431 - accuracy: 0.6772 - val_loss: 1.8015 - val_accuracy: 0.5549
# Epoch 38/100
# 391/391 [==============================] - ETA: 0s - loss: 1.1021 - accuracy: 0.6845
# Epoch 00038: val_accuracy improved from 0.55490 to 0.55830, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 1.1021 - accuracy: 0.6845 - val_loss: 1.8572 - val_accuracy: 0.5583
# Epoch 39/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0853 - accuracy: 0.6887
# Epoch 00039: val_accuracy improved from 0.55830 to 0.56230, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 131ms/step - loss: 1.0853 - accuracy: 0.6887 - val_loss: 1.8533 - val_accuracy: 0.5623
# Epoch 40/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0636 - accuracy: 0.6969
# Epoch 00040: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0636 - accuracy: 0.6969 - val_loss: 2.0414 - val_accuracy: 0.5399
# Epoch 41/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0308 - accuracy: 0.7054
# Epoch 00041: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0308 - accuracy: 0.7054 - val_loss: 1.9977 - val_accuracy: 0.5398
# Epoch 42/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0168 - accuracy: 0.7096
# Epoch 00042: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 1.0168 - accuracy: 0.7096 - val_loss: 1.9523 - val_accuracy: 0.5513
# Epoch 43/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9858 - accuracy: 0.7157
# Epoch 00043: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 131ms/step - loss: 0.9858 - accuracy: 0.7157 - val_loss: 1.8942 - val_accuracy: 0.5583
# Epoch 44/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9630 - accuracy: 0.7233
# Epoch 00044: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9630 - accuracy: 0.7233 - val_loss: 2.0096 - val_accuracy: 0.5544
# Epoch 45/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9555 - accuracy: 0.7238
# Epoch 00045: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9555 - accuracy: 0.7238 - val_loss: 2.0275 - val_accuracy: 0.5548
# Epoch 46/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9277 - accuracy: 0.7306
# Epoch 00046: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9277 - accuracy: 0.7306 - val_loss: 1.9658 - val_accuracy: 0.5504
# Epoch 47/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9101 - accuracy: 0.7356
# Epoch 00047: val_accuracy did not improve from 0.56230
# 391/391 [==============================] - 51s 130ms/step - loss: 0.9101 - accuracy: 0.7356 - val_loss: 2.0115 - val_accuracy: 0.5599
# Epoch 48/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8725 - accuracy: 0.7431
# Epoch 00048: val_accuracy improved from 0.56230 to 0.57140, saving model to ResNet_Basic_SGD.hdf5
# 391/391 [==============================] - 51s 129ms/step - loss: 0.8725 - accuracy: 0.7431 - val_loss: 1.8991 - val_accuracy: 0.5714
# Epoch 49/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8655 - accuracy: 0.7495
# Epoch 00049: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 50s 129ms/step - loss: 0.8655 - accuracy: 0.7495 - val_loss: 2.0388 - val_accuracy: 0.5501
# Epoch 50/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8450 - accuracy: 0.7524
# Epoch 00050: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 50s 128ms/step - loss: 0.8450 - accuracy: 0.7524 - val_loss: 1.9902 - val_accuracy: 0.5600
# Epoch 51/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8334 - accuracy: 0.7582
# Epoch 00051: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 50s 129ms/step - loss: 0.8334 - accuracy: 0.7582 - val_loss: 2.0089 - val_accuracy: 0.5691
# Epoch 52/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8088 - accuracy: 0.7633
# Epoch 00052: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 50s 129ms/step - loss: 0.8088 - accuracy: 0.7633 - val_loss: 2.0362 - val_accuracy: 0.5623
# Epoch 53/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7970 - accuracy: 0.7677
# Epoch 00053: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 50s 128ms/step - loss: 0.7970 - accuracy: 0.7677 - val_loss: 2.1680 - val_accuracy: 0.5529
# Epoch 54/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7654 - accuracy: 0.7732
# Epoch 00054: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 51s 130ms/step - loss: 0.7654 - accuracy: 0.7732 - val_loss: 2.0911 - val_accuracy: 0.5632
# Epoch 55/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7527 - accuracy: 0.7783
# Epoch 00055: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 51s 129ms/step - loss: 0.7527 - accuracy: 0.7783 - val_loss: 2.1314 - val_accuracy: 0.5617
# Epoch 56/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7555 - accuracy: 0.7790
# Epoch 00056: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 50s 127ms/step - loss: 0.7555 - accuracy: 0.7790 - val_loss: 2.2162 - val_accuracy: 0.5582
# Epoch 57/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7322 - accuracy: 0.7854
# Epoch 00057: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 49s 125ms/step - loss: 0.7322 - accuracy: 0.7854 - val_loss: 1.9909 - val_accuracy: 0.5660
# Epoch 58/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7238 - accuracy: 0.7878Restoring model weights from the end of the best epoch.
#
# Epoch 00058: val_accuracy did not improve from 0.57140
# 391/391 [==============================] - 49s 126ms/step - loss: 0.7238 - accuracy: 0.7878 - val_loss: 2.1236 - val_accuracy: 0.5623
# Epoch 00058: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.588448824821174
# Recall: 0.5714
# Accuracy: 0.5714

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# ## Cell to Load Weights and Print Results

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU,LeakyReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam,SGD

#Create Model
def relu_bn(inputs: Tensor) -> Tensor:
    relu = ReLU()(inputs)
    #bn = BatchNormalization()(relu)
    return relu

def residual_block(x: Tensor, downsample: bool, filters: int, kernel_size: int = 3) -> Tensor:
    y = Conv2D(kernel_size=kernel_size,strides= (1 if not downsample else 2),filters=filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(x)
    y = relu_bn(y)
    y = Conv2D(kernel_size=kernel_size,strides=1,filters=filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(y)

    if downsample:
        x = Conv2D(kernel_size=1,strides=2,filters=filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(x)

    out = Add()([x, y])
    out = relu_bn(out)
    return out

def create_res_net():
    
    inputs = Input(shape=(32, 32, 3))
    num_filters = 64
    
    #t = BatchNormalization()(inputs)
    t = Conv2D(kernel_size=3,strides=1,filters=num_filters,padding="same",kernel_initializer = glorot_uniform(seed=0))(inputs)
    t = relu_bn(t)
    
    num_blocks_list = [2,2,2,2]
    for i in range(len(num_blocks_list)):
        num_blocks = num_blocks_list[i]
        for j in range(num_blocks):
            t = residual_block(t, downsample=(j==0 and i!=0), filters=num_filters)
        num_filters *= 2
    
    t = AveragePooling2D(4)(t)
    t = Flatten()(t)
    t = Dense(512,activation='relu')(t)
    outputs = Dense(100, activation='softmax')(t)
    model = Model(inputs, outputs)
    sgd=SGD(learning_rate=0.01,momentum=0.9,clipnorm=1,name='sgd')
    model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])

    return model

from tensorflow.keras.datasets import cifar100
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard,EarlyStopping
from keras.utils import to_categorical

(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255

y_train = to_categorical(Y_train,100)
y_test = to_categorical(Y_test,100)

model = create_res_net()

model.load_weights('../weights/ResNet_Basic_SGD.hdf5')


# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
