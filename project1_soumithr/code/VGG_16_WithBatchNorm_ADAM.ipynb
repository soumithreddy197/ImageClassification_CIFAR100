# %%
from keras.datasets import cifar100
(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense,BatchNormalization,Activation,Dropout,LeakyReLU
from tensorflow.keras.optimizers import Adam
model = Sequential()

# Creating first block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same', input_shape= (32, 32, 3)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))

# Creating second block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))


# Creating third block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(2,2)))
#model.add(Dropout(0.5))

# Creating fourth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))

model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))

# Creating fifth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))

model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))

# Flattening the pooled image pixels
model.add(Flatten())

# Creating 2 Dense Layers
model.add(Dense(units= 512))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.5))

model.add(Dense(units= 512))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.5))

# Creating an output layer
model.add(Dense(units= 100, activation='softmax'))


adam=Adam(learning_rate=0.0001,clipnorm=1,name='adam')
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
#print(model.summary())

# %% [markdown]
# Code snippet taken and modified from https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("VGG_DropOut_Adam_weights.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto',restore_best_weights=True)
hist=model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_test, y_test),callbacks=[checkpoint,early])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 391/391 [==============================] - ETA: 0s - loss: 3.0630 - accuracy: 0.2714
# Epoch 00001: val_accuracy improved from -inf to 0.32490, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 99s 253ms/step - loss: 3.0630 - accuracy: 0.2714 - val_loss: 2.7000 - val_accuracy: 0.3249
# Epoch 2/50
# 391/391 [==============================] - ETA: 0s - loss: 2.0674 - accuracy: 0.4714
# Epoch 00002: val_accuracy improved from 0.32490 to 0.39760, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 2.0674 - accuracy: 0.4714 - val_loss: 2.3916 - val_accuracy: 0.3976
# Epoch 3/50
# 391/391 [==============================] - ETA: 0s - loss: 1.5694 - accuracy: 0.5885
# Epoch 00003: val_accuracy improved from 0.39760 to 0.48250, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 1.5694 - accuracy: 0.5885 - val_loss: 1.9915 - val_accuracy: 0.4825
# Epoch 4/50
# 391/391 [==============================] - ETA: 0s - loss: 1.1775 - accuracy: 0.6915
# Epoch 00004: val_accuracy improved from 0.48250 to 0.51550, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 1.1775 - accuracy: 0.6915 - val_loss: 1.8355 - val_accuracy: 0.5155
# Epoch 5/50
# 391/391 [==============================] - ETA: 0s - loss: 0.8357 - accuracy: 0.7889
# Epoch 00005: val_accuracy improved from 0.51550 to 0.53420, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.8357 - accuracy: 0.7889 - val_loss: 1.7724 - val_accuracy: 0.5342
# Epoch 6/50
# 391/391 [==============================] - ETA: 0s - loss: 0.5407 - accuracy: 0.8767
# Epoch 00006: val_accuracy did not improve from 0.53420
# 391/391 [==============================] - 97s 248ms/step - loss: 0.5407 - accuracy: 0.8767 - val_loss: 1.8498 - val_accuracy: 0.5266
# Epoch 7/50
# 391/391 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.9463
# Epoch 00007: val_accuracy improved from 0.53420 to 0.56560, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.3048 - accuracy: 0.9463 - val_loss: 1.6959 - val_accuracy: 0.5656
# Epoch 8/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9836
# Epoch 00008: val_accuracy did not improve from 0.56560
# 391/391 [==============================] - 97s 247ms/step - loss: 0.1406 - accuracy: 0.9836 - val_loss: 1.7255 - val_accuracy: 0.5637
# Epoch 9/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9948
# Epoch 00009: val_accuracy improved from 0.56560 to 0.57710, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0648 - accuracy: 0.9948 - val_loss: 1.6825 - val_accuracy: 0.5771
# Epoch 10/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9969
# Epoch 00010: val_accuracy improved from 0.57710 to 0.58620, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0384 - accuracy: 0.9969 - val_loss: 1.6842 - val_accuracy: 0.5862
# Epoch 11/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9979
# Epoch 00011: val_accuracy did not improve from 0.58620
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0293 - accuracy: 0.9979 - val_loss: 1.8302 - val_accuracy: 0.5647
# Epoch 12/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9965
# Epoch 00012: val_accuracy did not improve from 0.58620
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0326 - accuracy: 0.9965 - val_loss: 2.1474 - val_accuracy: 0.5136
# Epoch 13/50
# 391/391 [==============================] - ETA: 0s - loss: 0.2142 - accuracy: 0.9531
# Epoch 00013: val_accuracy did not improve from 0.58620
# 391/391 [==============================] - 97s 247ms/step - loss: 0.2142 - accuracy: 0.9531 - val_loss: 2.1314 - val_accuracy: 0.5093
# Epoch 14/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9856
# Epoch 00014: val_accuracy did not improve from 0.58620
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0906 - accuracy: 0.9856 - val_loss: 2.0098 - val_accuracy: 0.5430
# Epoch 15/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9980
# Epoch 00015: val_accuracy improved from 0.58620 to 0.60160, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0247 - accuracy: 0.9980 - val_loss: 1.7131 - val_accuracy: 0.6016
# Epoch 16/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9988
# Epoch 00016: val_accuracy did not improve from 0.60160
# 391/391 [==============================] - 97s 248ms/step - loss: 0.0110 - accuracy: 0.9988 - val_loss: 1.7771 - val_accuracy: 0.5895
# Epoch 17/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9992
# Epoch 00017: val_accuracy did not improve from 0.60160
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0079 - accuracy: 0.9992 - val_loss: 1.7361 - val_accuracy: 0.5960
# Epoch 18/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9743
# Epoch 00018: val_accuracy did not improve from 0.60160
# 391/391 [==============================] - 97s 247ms/step - loss: 0.1018 - accuracy: 0.9743 - val_loss: 2.8609 - val_accuracy: 0.4554
# Epoch 19/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9624
# Epoch 00019: val_accuracy did not improve from 0.60160
# 391/391 [==============================] - 97s 247ms/step - loss: 0.1544 - accuracy: 0.9624 - val_loss: 2.1113 - val_accuracy: 0.5305
# Epoch 20/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9973
# Epoch 00020: val_accuracy did not improve from 0.60160
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0250 - accuracy: 0.9973 - val_loss: 1.7855 - val_accuracy: 0.5956
# Epoch 21/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9994
# Epoch 00021: val_accuracy improved from 0.60160 to 0.61720, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 1.6975 - val_accuracy: 0.6172
# Epoch 22/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9995
# Epoch 00022: val_accuracy did not improve from 0.61720
# 391/391 [==============================] - 97s 248ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 1.7106 - val_accuracy: 0.6171
# Epoch 23/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9994
# Epoch 00023: val_accuracy improved from 0.61720 to 0.61750, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 1.7212 - val_accuracy: 0.6175
# Epoch 24/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9647
# Epoch 00024: val_accuracy did not improve from 0.61750
# 391/391 [==============================] - 97s 248ms/step - loss: 0.1232 - accuracy: 0.9647 - val_loss: 2.5872 - val_accuracy: 0.4875
# Epoch 25/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9686
# Epoch 00025: val_accuracy did not improve from 0.61750
# 391/391 [==============================] - 97s 247ms/step - loss: 0.1255 - accuracy: 0.9686 - val_loss: 2.0653 - val_accuracy: 0.5526
# Epoch 26/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9979
# Epoch 00026: val_accuracy did not improve from 0.61750
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0183 - accuracy: 0.9979 - val_loss: 1.8079 - val_accuracy: 0.5972
# Epoch 27/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9994
# Epoch 00027: val_accuracy did not improve from 0.61750
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 1.7616 - val_accuracy: 0.6141
# Epoch 28/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9994
# Epoch 00028: val_accuracy did not improve from 0.61750
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 1.7621 - val_accuracy: 0.6145
# Epoch 29/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9994
# Epoch 00029: val_accuracy did not improve from 0.61750
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 1.7909 - val_accuracy: 0.6117
# Epoch 30/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9994
# Epoch 00030: val_accuracy improved from 0.61750 to 0.61770, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 1.7477 - val_accuracy: 0.6177
# Epoch 31/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9994
# Epoch 00031: val_accuracy improved from 0.61770 to 0.62000, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 1.7788 - val_accuracy: 0.6200
# Epoch 32/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9993
# Epoch 00032: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 248ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 1.7701 - val_accuracy: 0.6166
# Epoch 33/50
# 391/391 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9318
# Epoch 00033: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 247ms/step - loss: 0.2231 - accuracy: 0.9318 - val_loss: 2.3446 - val_accuracy: 0.5150
# Epoch 34/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9780
# Epoch 00034: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0870 - accuracy: 0.9780 - val_loss: 2.0769 - val_accuracy: 0.5582
# Epoch 35/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9986
# Epoch 00035: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0119 - accuracy: 0.9986 - val_loss: 1.8151 - val_accuracy: 0.6065
# Epoch 36/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9994
# Epoch 00036: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 1.7724 - val_accuracy: 0.6184
# Epoch 37/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995
# Epoch 00037: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 1.7907 - val_accuracy: 0.6154
# Epoch 38/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994
# Epoch 00038: val_accuracy did not improve from 0.62000
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 1.7855 - val_accuracy: 0.6178
# Epoch 39/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 00039: val_accuracy improved from 0.62000 to 0.62070, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 1.7899 - val_accuracy: 0.6207
# Epoch 40/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995
# Epoch 00040: val_accuracy improved from 0.62070 to 0.62320, saving model to VGG_DropOut_Adam_weights.hdf5
# 391/391 [==============================] - 97s 249ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 1.7891 - val_accuracy: 0.6232
# Epoch 41/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9878
# Epoch 00041: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0417 - accuracy: 0.9878 - val_loss: 3.7939 - val_accuracy: 0.3934
# Epoch 42/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9506
# Epoch 00042: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.1690 - accuracy: 0.9506 - val_loss: 2.0470 - val_accuracy: 0.5695
# Epoch 43/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9986
# Epoch 00043: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0115 - accuracy: 0.9986 - val_loss: 1.8721 - val_accuracy: 0.6022
# Epoch 44/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9995
# Epoch 00044: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 1.8286 - val_accuracy: 0.6139
# Epoch 45/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 00045: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 1.8193 - val_accuracy: 0.6152
# Epoch 46/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 00046: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 1.8249 - val_accuracy: 0.6185
# Epoch 47/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 00047: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.8251 - val_accuracy: 0.6212
# Epoch 48/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00048: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 248ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 1.9511 - val_accuracy: 0.5900
# Epoch 49/50
# 391/391 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9575
# Epoch 00049: val_accuracy did not improve from 0.62320
# 391/391 [==============================] - 97s 247ms/step - loss: 0.1446 - accuracy: 0.9575 - val_loss: 2.1874 - val_accuracy: 0.5509
# Epoch 50/50
# 391/391 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9969
# Epoch 00050: val_accuracy did not improve from 0.62320
# Restoring model weights from the end of the best epoch.
# 391/391 [==============================] - 97s 248ms/step - loss: 0.0174 - accuracy: 0.9969 - val_loss: 1.9733 - val_accuracy: 0.5952
# Epoch 00050: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.6235230802714604
# Recall: 0.6232
# Accuracy: 0.6232

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense,BatchNormalization,Activation,Dropout,LeakyReLU
from tensorflow.keras.optimizers import Adam
model = Sequential()

# Creating first block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same', input_shape= (32, 32, 3)))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))

# Creating second block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))


# Creating third block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(2,2)))
#model.add(Dropout(0.5))

# Creating fourth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))

model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))

# Creating fifth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))

model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
#model.add(Dropout(0.5))

# Flattening the pooled image pixels
model.add(Flatten())

# Creating 2 Dense Layers
model.add(Dense(units= 512))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.5))

model.add(Dense(units= 512))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.5))

# Creating an output layer
model.add(Dense(units= 100, activation='softmax'))


adam=Adam(learning_rate=0.0001,clipnorm=1,name='adam')
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])
#print(model.summary())

from keras.datasets import cifar100
(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)

model.load_weights('../weights/VGG_BatchNorm_Adam_weights.hdf5')


# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Using TensorFlow backend.
# Prec: 0.6235230802714604
# Recall: 0.6232
# Accuracy: 0.6232
