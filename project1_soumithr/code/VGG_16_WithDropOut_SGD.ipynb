# %%
from keras.datasets import cifar100
(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense,BatchNormalization,Activation,Dropout,LeakyReLU
from tensorflow.keras.optimizers import SGD
#import tensorflow as 
model = Sequential()

# Creating first block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same', input_shape= (32, 32, 3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))

# Creating second block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))


# Creating third block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(2,2)))
model.add(Dropout(0.5))

# Creating fourth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.3))
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))

# Creating fifth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.3))
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))

# Flattening the pooled image pixels
model.add(Flatten())

# Creating 2 Dense Layers
model.add(Dense(units= 512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(units= 512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
#model.add(Dropout(0.3))
# Creating an output layer
model.add(Dense(units= 100, activation='softmax'))
'''
optimizer = tf.train.AdamOptimizer(learning_rate=0.1)
gvs = optimizer.compute_gradients(cost)
capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
train_op = optimizer.apply_gradients(capped_gvs)
'''
#adam=Adam(learning_rate=0.0001,clipnorm=1,name='adam')

sgd=SGD(learning_rate=0.01,momentum=0.9,clipnorm=1)
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])
#print(model.summary())

# %% [markdown]
# Code snippet taken and modified from https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint("VGG_DropOut_SGD_weights.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto',restore_best_weights=True)
hist=model.fit(x_train, y_train, batch_size=128, epochs=100, verbose=1, validation_data=(x_test, y_test),callbacks=[checkpoint,early])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/100
#   2/391 [..............................] - ETA: 1:21 - loss: 28.3943 - accuracy: 0.0078WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1602s vs `on_train_batch_end` time: 0.2562s). Check your callbacks.
# 391/391 [==============================] - ETA: 0s - loss: 4.7395 - accuracy: 0.0124
# Epoch 00001: val_accuracy improved from -inf to 0.01050, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 184s 471ms/step - loss: 4.7395 - accuracy: 0.0124 - val_loss: 4.6029 - val_accuracy: 0.0105
# Epoch 2/100
# 391/391 [==============================] - ETA: 0s - loss: 4.4389 - accuracy: 0.0266
# Epoch 00002: val_accuracy improved from 0.01050 to 0.01440, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 190s 486ms/step - loss: 4.4389 - accuracy: 0.0266 - val_loss: 4.6127 - val_accuracy: 0.0144
# Epoch 3/100
# 391/391 [==============================] - ETA: 0s - loss: 4.2445 - accuracy: 0.0454
# Epoch 00003: val_accuracy improved from 0.01440 to 0.02800, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 495ms/step - loss: 4.2445 - accuracy: 0.0454 - val_loss: 4.5903 - val_accuracy: 0.0280
# Epoch 4/100
# 391/391 [==============================] - ETA: 0s - loss: 4.0401 - accuracy: 0.0708
# Epoch 00004: val_accuracy improved from 0.02800 to 0.04900, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 495ms/step - loss: 4.0401 - accuracy: 0.0708 - val_loss: 4.3052 - val_accuracy: 0.0490
# Epoch 5/100
# 391/391 [==============================] - ETA: 0s - loss: 3.8409 - accuracy: 0.1008
# Epoch 00005: val_accuracy improved from 0.04900 to 0.11420, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 3.8409 - accuracy: 0.1008 - val_loss: 3.8336 - val_accuracy: 0.1142
# Epoch 6/100
# 391/391 [==============================] - ETA: 0s - loss: 3.6434 - accuracy: 0.1364
# Epoch 00006: val_accuracy improved from 0.11420 to 0.16050, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 495ms/step - loss: 3.6434 - accuracy: 0.1364 - val_loss: 3.5759 - val_accuracy: 0.1605
# Epoch 7/100
# 391/391 [==============================] - ETA: 0s - loss: 3.4535 - accuracy: 0.1702
# Epoch 00007: val_accuracy improved from 0.16050 to 0.20730, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 3.4535 - accuracy: 0.1702 - val_loss: 3.3052 - val_accuracy: 0.2073
# Epoch 8/100
# 391/391 [==============================] - ETA: 0s - loss: 3.2675 - accuracy: 0.2018
# Epoch 00008: val_accuracy improved from 0.20730 to 0.24020, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 3.2675 - accuracy: 0.2018 - val_loss: 3.1579 - val_accuracy: 0.2402
# Epoch 9/100
# 391/391 [==============================] - ETA: 0s - loss: 3.0987 - accuracy: 0.2356
# Epoch 00009: val_accuracy improved from 0.24020 to 0.27010, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 495ms/step - loss: 3.0987 - accuracy: 0.2356 - val_loss: 2.9706 - val_accuracy: 0.2701
# Epoch 10/100
# 391/391 [==============================] - ETA: 0s - loss: 2.9376 - accuracy: 0.2663
# Epoch 00010: val_accuracy improved from 0.27010 to 0.32120, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 2.9376 - accuracy: 0.2663 - val_loss: 2.7309 - val_accuracy: 0.3212
# Epoch 11/100
# 391/391 [==============================] - ETA: 0s - loss: 2.7765 - accuracy: 0.2960
# Epoch 00011: val_accuracy improved from 0.32120 to 0.32320, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 2.7765 - accuracy: 0.2960 - val_loss: 2.6993 - val_accuracy: 0.3232
# Epoch 12/100
# 391/391 [==============================] - ETA: 0s - loss: 2.6421 - accuracy: 0.3197
# Epoch 00012: val_accuracy improved from 0.32320 to 0.32600, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 495ms/step - loss: 2.6421 - accuracy: 0.3197 - val_loss: 2.6759 - val_accuracy: 0.3260
# Epoch 13/100
# 391/391 [==============================] - ETA: 0s - loss: 2.5073 - accuracy: 0.3491
# Epoch 00013: val_accuracy improved from 0.32600 to 0.38040, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 2.5073 - accuracy: 0.3491 - val_loss: 2.4106 - val_accuracy: 0.3804
# Epoch 14/100
# 391/391 [==============================] - ETA: 0s - loss: 2.4056 - accuracy: 0.3720
# Epoch 00014: val_accuracy improved from 0.38040 to 0.40080, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 2.4056 - accuracy: 0.3720 - val_loss: 2.3090 - val_accuracy: 0.4008
# Epoch 15/100
# 391/391 [==============================] - ETA: 0s - loss: 2.2943 - accuracy: 0.3945
# Epoch 00015: val_accuracy improved from 0.40080 to 0.40920, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 2.2943 - accuracy: 0.3945 - val_loss: 2.2664 - val_accuracy: 0.4092
# Epoch 16/100
# 391/391 [==============================] - ETA: 0s - loss: 2.2075 - accuracy: 0.4109
# Epoch 00016: val_accuracy did not improve from 0.40920
# 391/391 [==============================] - 193s 494ms/step - loss: 2.2075 - accuracy: 0.4109 - val_loss: 2.3348 - val_accuracy: 0.3995
# Epoch 17/100
# 391/391 [==============================] - ETA: 0s - loss: 2.1117 - accuracy: 0.4339
# Epoch 00017: val_accuracy improved from 0.40920 to 0.44910, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 2.1117 - accuracy: 0.4339 - val_loss: 2.0892 - val_accuracy: 0.4491
# Epoch 18/100
# 391/391 [==============================] - ETA: 0s - loss: 2.0162 - accuracy: 0.4531
# Epoch 00018: val_accuracy improved from 0.44910 to 0.45570, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 2.0162 - accuracy: 0.4531 - val_loss: 2.0604 - val_accuracy: 0.4557
# Epoch 19/100
# 391/391 [==============================] - ETA: 0s - loss: 1.9531 - accuracy: 0.4686
# Epoch 00019: val_accuracy improved from 0.45570 to 0.46710, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 1.9531 - accuracy: 0.4686 - val_loss: 1.9996 - val_accuracy: 0.4671
# Epoch 20/100
# 391/391 [==============================] - ETA: 0s - loss: 1.8832 - accuracy: 0.4827
# Epoch 00020: val_accuracy improved from 0.46710 to 0.48270, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 1.8832 - accuracy: 0.4827 - val_loss: 1.9380 - val_accuracy: 0.4827
# Epoch 21/100
# 391/391 [==============================] - ETA: 0s - loss: 1.8148 - accuracy: 0.5008
# Epoch 00021: val_accuracy did not improve from 0.48270
# 391/391 [==============================] - 194s 495ms/step - loss: 1.8148 - accuracy: 0.5008 - val_loss: 1.9890 - val_accuracy: 0.4706
# Epoch 22/100
# 391/391 [==============================] - ETA: 0s - loss: 1.7381 - accuracy: 0.5137
# Epoch 00022: val_accuracy improved from 0.48270 to 0.50290, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 1.7381 - accuracy: 0.5137 - val_loss: 1.8411 - val_accuracy: 0.5029
# Epoch 23/100
# 391/391 [==============================] - ETA: 0s - loss: 1.6869 - accuracy: 0.5293
# Epoch 00023: val_accuracy did not improve from 0.50290
# 391/391 [==============================] - 194s 495ms/step - loss: 1.6869 - accuracy: 0.5293 - val_loss: 1.8725 - val_accuracy: 0.4982
# Epoch 24/100
# 391/391 [==============================] - ETA: 0s - loss: 1.6318 - accuracy: 0.5436
# Epoch 00024: val_accuracy improved from 0.50290 to 0.52310, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.6318 - accuracy: 0.5436 - val_loss: 1.7675 - val_accuracy: 0.5231
# Epoch 25/100
# 391/391 [==============================] - ETA: 0s - loss: 1.5666 - accuracy: 0.5549
# Epoch 00025: val_accuracy did not improve from 0.52310
# 391/391 [==============================] - 194s 495ms/step - loss: 1.5666 - accuracy: 0.5549 - val_loss: 1.8298 - val_accuracy: 0.5119
# Epoch 26/100
# 391/391 [==============================] - ETA: 0s - loss: 1.5065 - accuracy: 0.5708
# Epoch 00026: val_accuracy improved from 0.52310 to 0.53180, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 1.5065 - accuracy: 0.5708 - val_loss: 1.7645 - val_accuracy: 0.5318
# Epoch 27/100
# 391/391 [==============================] - ETA: 0s - loss: 1.4553 - accuracy: 0.5834
# Epoch 00027: val_accuracy improved from 0.53180 to 0.54080, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.4553 - accuracy: 0.5834 - val_loss: 1.7113 - val_accuracy: 0.5408
# Epoch 28/100
# 391/391 [==============================] - ETA: 0s - loss: 1.4147 - accuracy: 0.5936
# Epoch 00028: val_accuracy did not improve from 0.54080
# 391/391 [==============================] - 193s 495ms/step - loss: 1.4147 - accuracy: 0.5936 - val_loss: 1.8123 - val_accuracy: 0.5287
# Epoch 29/100
# 391/391 [==============================] - ETA: 0s - loss: 1.3678 - accuracy: 0.6014
# Epoch 00029: val_accuracy did not improve from 0.54080
# 391/391 [==============================] - 193s 495ms/step - loss: 1.3678 - accuracy: 0.6014 - val_loss: 1.7257 - val_accuracy: 0.5342
# Epoch 30/100
# 391/391 [==============================] - ETA: 0s - loss: 1.3294 - accuracy: 0.6147
# Epoch 00030: val_accuracy improved from 0.54080 to 0.54810, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.3294 - accuracy: 0.6147 - val_loss: 1.7005 - val_accuracy: 0.5481
# Epoch 31/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2864 - accuracy: 0.6244
# Epoch 00031: val_accuracy improved from 0.54810 to 0.55330, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.2864 - accuracy: 0.6244 - val_loss: 1.6701 - val_accuracy: 0.5533
# Epoch 32/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2373 - accuracy: 0.6370
# Epoch 00032: val_accuracy did not improve from 0.55330
# 391/391 [==============================] - 194s 495ms/step - loss: 1.2373 - accuracy: 0.6370 - val_loss: 1.6924 - val_accuracy: 0.5514
# Epoch 33/100
# 391/391 [==============================] - ETA: 0s - loss: 1.2027 - accuracy: 0.6433
# Epoch 00033: val_accuracy improved from 0.55330 to 0.56180, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.2027 - accuracy: 0.6433 - val_loss: 1.6964 - val_accuracy: 0.5618
# Epoch 34/100
# 391/391 [==============================] - ETA: 0s - loss: 1.1623 - accuracy: 0.6539
# Epoch 00034: val_accuracy did not improve from 0.56180
# 391/391 [==============================] - 194s 496ms/step - loss: 1.1623 - accuracy: 0.6539 - val_loss: 1.6634 - val_accuracy: 0.5608
# Epoch 35/100
# 391/391 [==============================] - ETA: 0s - loss: 1.1240 - accuracy: 0.6635
# Epoch 00035: val_accuracy improved from 0.56180 to 0.56670, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 496ms/step - loss: 1.1240 - accuracy: 0.6635 - val_loss: 1.6255 - val_accuracy: 0.5667
# Epoch 36/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0890 - accuracy: 0.6728
# Epoch 00036: val_accuracy improved from 0.56670 to 0.56870, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.0890 - accuracy: 0.6728 - val_loss: 1.6266 - val_accuracy: 0.5687
# Epoch 37/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0626 - accuracy: 0.6800
# Epoch 00037: val_accuracy improved from 0.56870 to 0.57210, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 1.0626 - accuracy: 0.6800 - val_loss: 1.6460 - val_accuracy: 0.5721
# Epoch 38/100
# 391/391 [==============================] - ETA: 0s - loss: 1.0271 - accuracy: 0.6887
# Epoch 00038: val_accuracy did not improve from 0.57210
# 391/391 [==============================] - 194s 496ms/step - loss: 1.0271 - accuracy: 0.6887 - val_loss: 1.6667 - val_accuracy: 0.5618
# Epoch 39/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9955 - accuracy: 0.6975
# Epoch 00039: val_accuracy improved from 0.57210 to 0.57580, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 195s 498ms/step - loss: 0.9955 - accuracy: 0.6975 - val_loss: 1.6363 - val_accuracy: 0.5758
# Epoch 40/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9650 - accuracy: 0.7067
# Epoch 00040: val_accuracy did not improve from 0.57580
# 391/391 [==============================] - 194s 495ms/step - loss: 0.9650 - accuracy: 0.7067 - val_loss: 1.6618 - val_accuracy: 0.5753
# Epoch 41/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9430 - accuracy: 0.7119
# Epoch 00041: val_accuracy improved from 0.57580 to 0.57940, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 0.9430 - accuracy: 0.7119 - val_loss: 1.6493 - val_accuracy: 0.5794
# Epoch 42/100
# 391/391 [==============================] - ETA: 0s - loss: 0.9072 - accuracy: 0.7228
# Epoch 00042: val_accuracy did not improve from 0.57940
# 391/391 [==============================] - 194s 495ms/step - loss: 0.9072 - accuracy: 0.7228 - val_loss: 1.6616 - val_accuracy: 0.5777
# Epoch 43/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8804 - accuracy: 0.7284
# Epoch 00043: val_accuracy did not improve from 0.57940
# 391/391 [==============================] - 193s 495ms/step - loss: 0.8804 - accuracy: 0.7284 - val_loss: 1.6759 - val_accuracy: 0.5742
# Epoch 44/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8645 - accuracy: 0.7347
# Epoch 00044: val_accuracy improved from 0.57940 to 0.58160, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 0.8645 - accuracy: 0.7347 - val_loss: 1.6928 - val_accuracy: 0.5816
# Epoch 45/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8379 - accuracy: 0.7436
# Epoch 00045: val_accuracy improved from 0.58160 to 0.58310, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 0.8379 - accuracy: 0.7436 - val_loss: 1.6724 - val_accuracy: 0.5831
# Epoch 46/100
# 391/391 [==============================] - ETA: 0s - loss: 0.8105 - accuracy: 0.7492
# Epoch 00046: val_accuracy improved from 0.58310 to 0.58410, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 0.8105 - accuracy: 0.7492 - val_loss: 1.6698 - val_accuracy: 0.5841
# Epoch 47/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7906 - accuracy: 0.7541
# Epoch 00047: val_accuracy did not improve from 0.58410
# 391/391 [==============================] - 194s 495ms/step - loss: 0.7906 - accuracy: 0.7541 - val_loss: 1.7071 - val_accuracy: 0.5837
# Epoch 48/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7675 - accuracy: 0.7607
# Epoch 00048: val_accuracy did not improve from 0.58410
# 391/391 [==============================] - 194s 496ms/step - loss: 0.7675 - accuracy: 0.7607 - val_loss: 1.7632 - val_accuracy: 0.5727
# Epoch 49/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.7668
# Epoch 00049: val_accuracy improved from 0.58410 to 0.59210, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 0.7535 - accuracy: 0.7668 - val_loss: 1.6917 - val_accuracy: 0.5921
# Epoch 50/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7371 - accuracy: 0.7728
# Epoch 00050: val_accuracy did not improve from 0.59210
# 391/391 [==============================] - 194s 496ms/step - loss: 0.7371 - accuracy: 0.7728 - val_loss: 1.6625 - val_accuracy: 0.5872
# Epoch 51/100
# 391/391 [==============================] - ETA: 0s - loss: 0.7128 - accuracy: 0.7764
# Epoch 00051: val_accuracy did not improve from 0.59210
# 391/391 [==============================] - 194s 495ms/step - loss: 0.7128 - accuracy: 0.7764 - val_loss: 1.7223 - val_accuracy: 0.5905
# Epoch 52/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6998 - accuracy: 0.7824
# Epoch 00052: val_accuracy did not improve from 0.59210
# 391/391 [==============================] - 194s 495ms/step - loss: 0.6998 - accuracy: 0.7824 - val_loss: 1.8167 - val_accuracy: 0.5802
# Epoch 53/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.7874
# Epoch 00053: val_accuracy did not improve from 0.59210
# 391/391 [==============================] - 194s 495ms/step - loss: 0.6802 - accuracy: 0.7874 - val_loss: 1.7862 - val_accuracy: 0.5812
# Epoch 54/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.7928
# Epoch 00054: val_accuracy improved from 0.59210 to 0.59380, saving model to VGG_DropOut_SGD_weights.hdf5
# 391/391 [==============================] - 194s 497ms/step - loss: 0.6615 - accuracy: 0.7928 - val_loss: 1.7306 - val_accuracy: 0.5938
# Epoch 55/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.7977
# Epoch 00055: val_accuracy did not improve from 0.59380
# 391/391 [==============================] - 194s 495ms/step - loss: 0.6440 - accuracy: 0.7977 - val_loss: 1.7302 - val_accuracy: 0.5848
# Epoch 56/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6243 - accuracy: 0.8024
# Epoch 00056: val_accuracy did not improve from 0.59380
# 391/391 [==============================] - 194s 496ms/step - loss: 0.6243 - accuracy: 0.8024 - val_loss: 1.7235 - val_accuracy: 0.5919
# Epoch 57/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.8072
# Epoch 00057: val_accuracy did not improve from 0.59380
# 391/391 [==============================] - 193s 495ms/step - loss: 0.6158 - accuracy: 0.8072 - val_loss: 1.7907 - val_accuracy: 0.5898
# Epoch 58/100
# 391/391 [==============================] - ETA: 0s - loss: 0.6008 - accuracy: 0.8115
# Epoch 00058: val_accuracy did not improve from 0.59380
# 391/391 [==============================] - 194s 496ms/step - loss: 0.6008 - accuracy: 0.8115 - val_loss: 1.8679 - val_accuracy: 0.5865
# Epoch 59/100
# 391/391 [==============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.8167
# Epoch 00059: val_accuracy did not improve from 0.59380
# Restoring model weights from the end of the best epoch.
# 391/391 [==============================] - 194s 495ms/step - loss: 0.5878 - accuracy: 0.8167 - val_loss: 1.8610 - val_accuracy: 0.5794
# Epoch 00059: early stopping

# %%
# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
# Out:
# Prec: 0.6053969156260096
# Recall: 0.5938
# Accuracy: 0.5938

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history["accuracy"])
plt.plot(hist.history['val_accuracy'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# ## Cell to Load Weights and Print Results

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense,BatchNormalization,Activation,Dropout,LeakyReLU
from tensorflow.keras.optimizers import SGD
#import tensorflow as 
model = Sequential()

# Creating first block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same', input_shape= (32, 32, 3)))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 64, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))

# Creating second block- (2 Convolution + 1 Max pool)
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 128, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))


# Creating third block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 256, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size= (2,2), strides=(2,2)))
model.add(Dropout(0.5))

# Creating fourth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.3))
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))

# Creating fifth block- (3 Convolution + 1 Max pool)
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Conv2D(filters= 512, kernel_size= (3,3), strides= (1,1), padding='same'))
model.add(LeakyReLU(alpha=0.1))
#model.add(Dropout(0.3))
model.add(MaxPool2D(pool_size= (2,2), strides=(1,1)))
model.add(Dropout(0.5))

# Flattening the pooled image pixels
model.add(Flatten())

# Creating 2 Dense Layers
model.add(Dense(units= 512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
model.add(Dense(units= 512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.5))
#model.add(Dropout(0.3))
# Creating an output layer
model.add(Dense(units= 100, activation='softmax'))
#adam=Adam(learning_rate=0.0001,clipnorm=1,name='adam')

sgd=SGD(learning_rate=0.01,momentum=0.9,clipnorm=1)
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])
#print(model.summary())

from keras.datasets import cifar100
(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()
#x_train = x_train.astype('float32') / 255
#x_test = x_test.astype('float32') / 255
from keras.utils import to_categorical
y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)

model.load_weights('../weights/VGG_DropOut_SGD_weights.hdf5')

# Test the model
y_true = y_test.argmax(-1)
y_pred = model.predict(x_test).argmax(-1)
# generate confusion matrix
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
confusion_matrix(y_true, y_pred)
# calculate prec, recall, accuracy
print("Prec: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
